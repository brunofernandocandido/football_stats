# %% [markdown]
# <a href="https://colab.research.google.com/github/brunofernandocandido/football_stats/blob/main/teams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lendo dataset do github

# %%
url = 'https://raw.githubusercontent.com/brunofernandocandido/football_stats/main/foot_stats.xlsx'
df=pd.read_excel(url)

# %% [markdown]
# Printar 5 primeiras e ultimas linhas

# %%
df
# Out:
#                       Time   P  PJ   V   E   D  GP  GC  Pts  QG  \
# 0         Barcelona  - ESP   1  29  23   4   2  53   9   73  17
# 1            Napoli  - ITA   1  30  24   3   3  66  21   75  21
# 2         Paris S-G  - FRA   1  32  24   3   5  75  31   75  22
# 3           Arsenal  - ENG   1  32  23   6   3  77  34   75  15
# 4   Manchester City  - ENG   2  30  22   4   4  78  28   70  32
# ..                     ...  ..  ..  ..  ..  ..  ..  ..  ...  ..
# 93          Ajaccio  - FRA  19  31   6   3  22  22  58   21   6
# 94        Cremonese  - ITA  19  30   3  10  17  27  54   19   6
# 95        Sampdoria  - ITA  20  31   3   8  20  20  52   17   6
# 96            Elche  - ESP  20  29   2   7  20  20  59   13   6
# 97           Angers  - FRA  20  32   3   5  24  25  68   14   4
#
#                        Top Team Scorer
# 0                  Robert Lewandowski
# 1                      Victor Osimhen
# 2                       Kylian Mbappé
# 3                          Martinelli
# ...

# %% [markdown]
# Calcula a diferença de saldo de gols de cada time

# %%
df['GP'] - df['GC']
# Out:
# 0     44
# 1     45
# 2     44
# 3     43
# 4     50
#       ..
# 93   -36
# 94   -27
# 95   -32
# 96   -39
# 97   -43
# Length: 98, dtype: int64

# %% [markdown]
# Calcula a média de gols por jogo

# %%
df['GP'] / df['PJ']
# Out:
# 0     1.827586
# 1     2.200000
# 2     2.343750
# 3     2.406250
# 4     2.600000
#         ...
# 93    0.709677
# 94    0.900000
# 95    0.645161
# 96    0.689655
# 97    0.781250
# Length: 98, dtype: float64

# %% [markdown]
# Calcula a média de pontos por jogo

# %%
df['Pts'] / df['PJ']
# Out:
# 0     2.517241
# 1     2.500000
# 2     2.343750
# 3     2.343750
# 4     2.333333
#         ...
# 93    0.677419
# 94    0.633333
# 95    0.548387
# 96    0.448276
# 97    0.437500
# Length: 98, dtype: float64

# %% [markdown]
# Artilheiros e quantidade de gols

# %%
df[['Top Team Scorer', 'QG']]
# Out:
#                        Top Team Scorer  QG
# 0                  Robert Lewandowski   17
# 1                      Victor Osimhen   21
# 2                       Kylian Mbappé   22
# 3                          Martinelli   15
# 4                      Erling Haaland   32
# ..                                 ...  ..
# 93  Youcef Belaïli Mounaim El Idrissy    6
# 94      Cyriel Dessers Daniel Ciofani    6
# 95                  Manolo Gabbiadini    6
# 96                         Pere Milla    6
# 97        Adrien Hunou Sofiane Boufal    4
#
# [98 rows x 2 columns]

# %% [markdown]
# Melhor aproveitamento da temporada

# %%
df.sort_values("Pts")
# Out:
#                       Time   P  PJ   V   E   D  GP  GC  Pts  QG  \
# 96            Elche  - ESP  20  29   2   7  20  20  59   13   6
# 97           Angers  - FRA  20  32   3   5  24  25  68   14   4
# 95        Sampdoria  - ITA  20  31   3   8  20  20  52   17   6
# 94        Cremonese  - ITA  19  30   3  10  17  27  54   19   6
# 93          Ajaccio  - FRA  19  31   6   3  22  22  58   21   6
# ..                     ...  ..  ..  ..  ..  ..  ..  ..  ...  ..
# 4   Manchester City  - ENG   2  30  22   4   4  78  28   70  32
# 0         Barcelona  - ESP   1  29  23   4   2  53   9   73  17
# 3           Arsenal  - ENG   1  32  23   6   3  77  34   75  15
# 2         Paris S-G  - FRA   1  32  24   3   5  75  31   75  22
# 1            Napoli  - ITA   1  30  24   3   3  66  21   75  21
#
#                        Top Team Scorer
# 96                         Pere Milla
# 97        Adrien Hunou Sofiane Boufal
# 95                  Manolo Gabbiadini
# 94      Cyriel Dessers Daniel Ciofani
# ...

# %% [markdown]
# Melhor ataque da temporada

# %%
df.sort_values("GP")
# Out:
#                       Time   P  PJ   V   E   D  GP  GC  Pts  QG  \
# 96            Elche  - ESP  20  29   2   7  20  20  59   13   6
# 95        Sampdoria  - ITA  20  31   3   8  20  20  52   17   6
# 93          Ajaccio  - FRA  19  31   6   3  22  22  58   21   6
# 66            Cádiz  - ESP  15  30   7  11  12  23  42   32   3
# 84          Everton  - ENG  18  32   6  10  16  24  46   28   4
# ..                     ...  ..  ..  ..  ..  ..  ..  ..  ...  ..
# 14           Monaco  - FRA   4  32  18   7   7  66  46   61  17
# 2         Paris S-G  - FRA   1  32  24   3   5  75  31   75  22
# 3           Arsenal  - ENG   1  32  23   6   3  77  34   75  15
# 4   Manchester City  - ENG   2  30  22   4   4  78  28   70  32
# 10    Bayern Munich  - GER   2  29  17   8   4  79  33   59  11
#
#                        Top Team Scorer
# 96                         Pere Milla
# 95                  Manolo Gabbiadini
# 93  Youcef Belaïli Mounaim El Idrissy
# 66      Álex Fernández Lucas Pérez...
# ...

# %% [markdown]
# Melhor defesa da temporada

# %%
df.sort_values("GC")
# Out:
#                       Time   P  PJ   V   E   D  GP  GC  Pts  QG  \
# 0         Barcelona  - ESP   1  29  23   4   2  53   9   73  17
# 1            Napoli  - ITA   1  30  24   3   3  66  21   75  21
# 11            Lazio  - ITA   2  31  18   7   6  49  21   61  10
# 7   Atlético Madrid  - ESP   3  29  18   6   5  47  21   60  11
# 15    Newcastle Utd  - ENG   4  30  15  11   4  48  24   56  11
# ..                     ...  ..  ..  ..  ..  ..  ..  ..  ...  ..
# 69      Bournemouth  - ENG  14  31   9   6  16  31  59   33   7
# 82     Leeds United  - ENG  16  32   7   8  17  41  62   29  11
# 81           Bochum  - GER  15  29   8   3  18  32  66   27   8
# 92           Troyes  - FRA  18  31   4   9  18  39  67   21  11
# 97           Angers  - FRA  20  32   3   5  24  25  68   14   4
#
#                    Top Team Scorer
# 0              Robert Lewandowski
# 1                  Victor Osimhen
# 11  Ciro Immobile Mattia Zaccagni
# 7               Antoine Griezmann
# ...

# %% [markdown]
# HIstograma de pontos

# %%
plt.subplot(1,4,1) 
plt.hist(df['Pts'], ec="black") 
plt.title('Pontos')
plt.xlabel('Pontos')
plt.ylabel('Equipes')
# Out:
# Text(0, 0.5, 'Equipes')

# %% [markdown]
# Comparação de gols e posições na tabela

# %%
df[['Time', 'P', 'Top Team Scorer', 'QG']]
# Out:
#                       Time   P                     Top Team Scorer  QG
# 0         Barcelona  - ESP   1                 Robert Lewandowski   17
# 1            Napoli  - ITA   1                     Victor Osimhen   21
# 2         Paris S-G  - FRA   1                      Kylian Mbappé   22
# 3           Arsenal  - ENG   1                         Martinelli   15
# 4   Manchester City  - ENG   2                     Erling Haaland   32
# ..                     ...  ..                                 ...  ..
# 93          Ajaccio  - FRA  19  Youcef Belaïli Mounaim El Idrissy    6
# 94        Cremonese  - ITA  19      Cyriel Dessers Daniel Ciofani    6
# 95        Sampdoria  - ITA  20                  Manolo Gabbiadini    6
# 96            Elche  - ESP  20                         Pere Milla    6
# 97           Angers  - FRA  20        Adrien Hunou Sofiane Boufal    4
#
# [98 rows x 4 columns]
